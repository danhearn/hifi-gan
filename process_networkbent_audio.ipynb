# %% [markdown]
# This code is for preprocessing the network bent audio for use in training. Increasing gain and resampling to 44.1k.

# %%
import os
from pydub import AudioSegment
from pydub.effects import compress_dynamic_range
import librosa
import soundfile as sf
import numpy as np

def process_audio_files(input_folder, output_folder, gain_increase=10.0, target_sample_rate=44100):
    """
    Batch processes audio files to increase gain, resample to a target sample rate,
    and apply dynamic range compression.

    Args:
    - input_folder (str): Path to the folder containing input audio files.
    - output_folder (str): Path to the folder to save processed audio files.
    - gain_increase (float): Gain adjustment in dB (default is +5 dB).
    - target_sample_rate (int): Desired sample rate (default is 44100 Hz).
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate over all audio files in the input folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.wav', '.mp3', '.flac', '.ogg', '.m4a')):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, f"processed_{filename}")

            # Load audio using pydub
            audio = AudioSegment.from_file(input_path)

            # Increase gain
            audio = audio + gain_increase

            # Resample audio
            samples = np.array(audio.get_array_of_samples()).astype(np.float32)

            resampled_audio = librosa.resample(
                y=samples, orig_sr=audio.frame_rate, target_sr=target_sample_rate, res_type='kaiser_best'
            )

            # Apply compression
            audio = compress_dynamic_range(audio)

            # Export the processed audio
            audio.export(output_path, format="wav")
            print(f"Processed {filename} -> {output_path}")
# Out:
# c:\Users\danhearn\.conda\envs\hifigan\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
input_folder = r"C:\\Users\\danhearn\\Documents\\GitHub\\diffusertrack\\recorded_audio"
output_folder = "processed_networkbent_audio"
process_audio_files(input_folder, output_folder)
# Out:
# Processed data_1.wav -> processed_networkbent_audio\processed_data_1.wav
# Processed data_10.wav -> processed_networkbent_audio\processed_data_10.wav
# Processed data_100.wav -> processed_networkbent_audio\processed_data_100.wav
# Processed data_101.wav -> processed_networkbent_audio\processed_data_101.wav
# Processed data_102.wav -> processed_networkbent_audio\processed_data_102.wav
# Processed data_103.wav -> processed_networkbent_audio\processed_data_103.wav
# Processed data_104.wav -> processed_networkbent_audio\processed_data_104.wav
# Processed data_105.wav -> processed_networkbent_audio\processed_data_105.wav
# Processed data_106.wav -> processed_networkbent_audio\processed_data_106.wav
# Processed data_107.wav -> processed_networkbent_audio\processed_data_107.wav
# Processed data_108.wav -> processed_networkbent_audio\processed_data_108.wav
# Processed data_109.wav -> processed_networkbent_audio\processed_data_109.wav
# Processed data_11.wav -> processed_networkbent_audio\processed_data_11.wav
# Processed data_110.wav -> processed_networkbent_audio\processed_data_110.wav
# Processed data_111.wav -> processed_networkbent_audio\processed_data_111.wav
# Processed data_112.wav -> processed_networkbent_audio\processed_data_112.wav
# Processed data_113.wav -> processed_networkbent_audio\processed_data_113.wav
# Processed data_114.wav -> processed_networkbent_audio\processed_data_114.wav
# Processed data_115.wav -> processed_networkbent_audio\processed_data_115.wav
# Processed data_116.wav -> processed_networkbent_audio\processed_data_116.wav
# Processed data_117.wav -> processed_networkbent_audio\processed_data_117.wav
# Processed data_118.wav -> processed_networkbent_audio\processed_data_118.wav
# Processed data_119.wav -> processed_networkbent_audio\processed_data_119.wav
# Processed data_12.wav -> processed_networkbent_audio\processed_data_12.wav
# Processed data_120.wav -> processed_networkbent_audio\processed_data_120.wav
# Processed data_121.wav -> processed_networkbent_audio\processed_data_121.wav
# Processed data_122.wav -> processed_networkbent_audio\processed_data_122.wav
# Processed data_123.wav -> processed_networkbent_audio\processed_data_123.wav
# Processed data_124.wav -> processed_networkbent_audio\processed_data_124.wav
# Processed data_125.wav -> processed_networkbent_audio\processed_data_125.wav
# Processed data_126.wav -> processed_networkbent_audio\processed_data_126.wav
# Processed data_127.wav -> processed_networkbent_audio\processed_data_127.wav
# Processed data_128.wav -> processed_networkbent_audio\processed_data_128.wav
# Processed data_129.wav -> processed_networkbent_audio\processed_data_129.wav
# Processed data_13.wav -> processed_networkbent_audio\processed_data_13.wav
# Processed data_130.wav -> processed_networkbent_audio\processed_data_130.wav
# Processed data_131.wav -> processed_networkbent_audio\processed_data_131.wav
# Processed data_132.wav -> processed_networkbent_audio\processed_data_132.wav
# Processed data_133.wav -> processed_networkbent_audio\processed_data_133.wav
# Processed data_134.wav -> processed_networkbent_audio\processed_data_134.wav
# Processed data_135.wav -> processed_networkbent_audio\processed_data_135.wav
# Processed data_136.wav -> processed_networkbent_audio\processed_data_136.wav
# Processed data_137.wav -> processed_networkbent_audio\processed_data_137.wav
# Processed data_138.wav -> processed_networkbent_audio\processed_data_138.wav
# Processed data_139.wav -> processed_networkbent_audio\processed_data_139.wav
# Processed data_14.wav -> processed_networkbent_audio\processed_data_14.wav
# Processed data_140.wav -> processed_networkbent_audio\processed_data_140.wav
# Processed data_141.wav -> processed_networkbent_audio\processed_data_141.wav
# Processed data_142.wav -> processed_networkbent_audio\processed_data_142.wav
# Processed data_143.wav -> processed_networkbent_audio\processed_data_143.wav
# Processed data_144.wav -> processed_networkbent_audio\processed_data_144.wav
# Processed data_145.wav -> processed_networkbent_audio\processed_data_145.wav
# Processed data_146.wav -> processed_networkbent_audio\processed_data_146.wav
# Processed data_147.wav -> processed_networkbent_audio\processed_data_147.wav
# Processed data_148.wav -> processed_networkbent_audio\processed_data_148.wav
# Processed data_149.wav -> processed_networkbent_audio\processed_data_149.wav
# Processed data_15.wav -> processed_networkbent_audio\processed_data_15.wav
# Processed data_150.wav -> processed_networkbent_audio\processed_data_150.wav
# Processed data_151.wav -> processed_networkbent_audio\processed_data_151.wav
# Processed data_152.wav -> processed_networkbent_audio\processed_data_152.wav
# Processed data_153.wav -> processed_networkbent_audio\processed_data_153.wav
# Processed data_154.wav -> processed_networkbent_audio\processed_data_154.wav
# Processed data_155.wav -> processed_networkbent_audio\processed_data_155.wav
# Processed data_156.wav -> processed_networkbent_audio\processed_data_156.wav
# Processed data_157.wav -> processed_networkbent_audio\processed_data_157.wav
# Processed data_158.wav -> processed_networkbent_audio\processed_data_158.wav
# Processed data_159.wav -> processed_networkbent_audio\processed_data_159.wav
# Processed data_16.wav -> processed_networkbent_audio\processed_data_16.wav
# Processed data_160.wav -> processed_networkbent_audio\processed_data_160.wav
# Processed data_161.wav -> processed_networkbent_audio\processed_data_161.wav
# Processed data_162.wav -> processed_networkbent_audio\processed_data_162.wav
# Processed data_163.wav -> processed_networkbent_audio\processed_data_163.wav
# Processed data_164.wav -> processed_networkbent_audio\processed_data_164.wav
# Processed data_165.wav -> processed_networkbent_audio\processed_data_165.wav
# Processed data_166.wav -> processed_networkbent_audio\processed_data_166.wav
# Processed data_167.wav -> processed_networkbent_audio\processed_data_167.wav
# Processed data_168.wav -> processed_networkbent_audio\processed_data_168.wav
# Processed data_169.wav -> processed_networkbent_audio\processed_data_169.wav
# Processed data_17.wav -> processed_networkbent_audio\processed_data_17.wav
# Processed data_170.wav -> processed_networkbent_audio\processed_data_170.wav
# Processed data_171.wav -> processed_networkbent_audio\processed_data_171.wav
# Processed data_172.wav -> processed_networkbent_audio\processed_data_172.wav
# Processed data_173.wav -> processed_networkbent_audio\processed_data_173.wav
# Processed data_174.wav -> processed_networkbent_audio\processed_data_174.wav
# Processed data_175.wav -> processed_networkbent_audio\processed_data_175.wav
# Processed data_176.wav -> processed_networkbent_audio\processed_data_176.wav
# Processed data_177.wav -> processed_networkbent_audio\processed_data_177.wav
# Processed data_178.wav -> processed_networkbent_audio\processed_data_178.wav
# Processed data_179.wav -> processed_networkbent_audio\processed_data_179.wav
# Processed data_18.wav -> processed_networkbent_audio\processed_data_18.wav
# Processed data_180.wav -> processed_networkbent_audio\processed_data_180.wav
# Processed data_181.wav -> processed_networkbent_audio\processed_data_181.wav
# Processed data_182.wav -> processed_networkbent_audio\processed_data_182.wav
# Processed data_183.wav -> processed_networkbent_audio\processed_data_183.wav
# Processed data_184.wav -> processed_networkbent_audio\processed_data_184.wav
# Processed data_185.wav -> processed_networkbent_audio\processed_data_185.wav
# Processed data_186.wav -> processed_networkbent_audio\processed_data_186.wav
# Processed data_187.wav -> processed_networkbent_audio\processed_data_187.wav
# Processed data_188.wav -> processed_networkbent_audio\processed_data_188.wav
# Processed data_189.wav -> processed_networkbent_audio\processed_data_189.wav
# Processed data_19.wav -> processed_networkbent_audio\processed_data_19.wav
# Processed data_190.wav -> processed_networkbent_audio\processed_data_190.wav
# Processed data_191.wav -> processed_networkbent_audio\processed_data_191.wav
# Processed data_192.wav -> processed_networkbent_audio\processed_data_192.wav
# Processed data_193.wav -> processed_networkbent_audio\processed_data_193.wav
# Processed data_194.wav -> processed_networkbent_audio\processed_data_194.wav
# Processed data_195.wav -> processed_networkbent_audio\processed_data_195.wav
# Processed data_196.wav -> processed_networkbent_audio\processed_data_196.wav
# Processed data_197.wav -> processed_networkbent_audio\processed_data_197.wav
# Processed data_198.wav -> processed_networkbent_audio\processed_data_198.wav
# Processed data_199.wav -> processed_networkbent_audio\processed_data_199.wav
# Processed data_2.wav -> processed_networkbent_audio\processed_data_2.wav
# Processed data_20.wav -> processed_networkbent_audio\processed_data_20.wav
# Processed data_200.wav -> processed_networkbent_audio\processed_data_200.wav
# Processed data_201.wav -> processed_networkbent_audio\processed_data_201.wav
# Processed data_202.wav -> processed_networkbent_audio\processed_data_202.wav
# Processed data_203.wav -> processed_networkbent_audio\processed_data_203.wav
# Processed data_204.wav -> processed_networkbent_audio\processed_data_204.wav
# Processed data_205.wav -> processed_networkbent_audio\processed_data_205.wav
# Processed data_206.wav -> processed_networkbent_audio\processed_data_206.wav
# Processed data_207.wav -> processed_networkbent_audio\processed_data_207.wav
# Processed data_208.wav -> processed_networkbent_audio\processed_data_208.wav
# Processed data_209.wav -> processed_networkbent_audio\processed_data_209.wav
# Processed data_21.wav -> processed_networkbent_audio\processed_data_21.wav
# Processed data_210.wav -> processed_networkbent_audio\processed_data_210.wav
# Processed data_211.wav -> processed_networkbent_audio\processed_data_211.wav
# Processed data_212.wav -> processed_networkbent_audio\processed_data_212.wav
# Processed data_213.wav -> processed_networkbent_audio\processed_data_213.wav
# Processed data_214.wav -> processed_networkbent_audio\processed_data_214.wav
# Processed data_215.wav -> processed_networkbent_audio\processed_data_215.wav
# Processed data_216.wav -> processed_networkbent_audio\processed_data_216.wav
# Processed data_217.wav -> processed_networkbent_audio\processed_data_217.wav
# Processed data_218.wav -> processed_networkbent_audio\processed_data_218.wav
# Processed data_219.wav -> processed_networkbent_audio\processed_data_219.wav
# Processed data_22.wav -> processed_networkbent_audio\processed_data_22.wav
# Processed data_220.wav -> processed_networkbent_audio\processed_data_220.wav
# Processed data_221.wav -> processed_networkbent_audio\processed_data_221.wav
# Processed data_222.wav -> processed_networkbent_audio\processed_data_222.wav
# Processed data_223.wav -> processed_networkbent_audio\processed_data_223.wav
# Processed data_224.wav -> processed_networkbent_audio\processed_data_224.wav
# Processed data_225.wav -> processed_networkbent_audio\processed_data_225.wav
# Processed data_226.wav -> processed_networkbent_audio\processed_data_226.wav
# Processed data_227.wav -> processed_networkbent_audio\processed_data_227.wav
# Processed data_228.wav -> processed_networkbent_audio\processed_data_228.wav
# Processed data_229.wav -> processed_networkbent_audio\processed_data_229.wav
# Processed data_23.wav -> processed_networkbent_audio\processed_data_23.wav
# Processed data_230.wav -> processed_networkbent_audio\processed_data_230.wav
# Processed data_231.wav -> processed_networkbent_audio\processed_data_231.wav
# Processed data_232.wav -> processed_networkbent_audio\processed_data_232.wav
# Processed data_233.wav -> processed_networkbent_audio\processed_data_233.wav
# Processed data_234.wav -> processed_networkbent_audio\processed_data_234.wav
# Processed data_235.wav -> processed_networkbent_audio\processed_data_235.wav
# Processed data_236.wav -> processed_networkbent_audio\processed_data_236.wav
# Processed data_237.wav -> processed_networkbent_audio\processed_data_237.wav
# Processed data_238.wav -> processed_networkbent_audio\processed_data_238.wav
# Processed data_239.wav -> processed_networkbent_audio\processed_data_239.wav
# Processed data_24.wav -> processed_networkbent_audio\processed_data_24.wav
# Processed data_240.wav -> processed_networkbent_audio\processed_data_240.wav
# Processed data_241.wav -> processed_networkbent_audio\processed_data_241.wav
# Processed data_242.wav -> processed_networkbent_audio\processed_data_242.wav
# Processed data_243.wav -> processed_networkbent_audio\processed_data_243.wav
# Processed data_244.wav -> processed_networkbent_audio\processed_data_244.wav
# Processed data_245.wav -> processed_networkbent_audio\processed_data_245.wav
# Processed data_246.wav -> processed_networkbent_audio\processed_data_246.wav
# Processed data_247.wav -> processed_networkbent_audio\processed_data_247.wav
# Processed data_248.wav -> processed_networkbent_audio\processed_data_248.wav
# Processed data_249.wav -> processed_networkbent_audio\processed_data_249.wav
# Processed data_25.wav -> processed_networkbent_audio\processed_data_25.wav
# Processed data_250.wav -> processed_networkbent_audio\processed_data_250.wav
# Processed data_251.wav -> processed_networkbent_audio\processed_data_251.wav
# Processed data_252.wav -> processed_networkbent_audio\processed_data_252.wav
# Processed data_253.wav -> processed_networkbent_audio\processed_data_253.wav
# Processed data_254.wav -> processed_networkbent_audio\processed_data_254.wav
# Processed data_255.wav -> processed_networkbent_audio\processed_data_255.wav
# Processed data_256.wav -> processed_networkbent_audio\processed_data_256.wav
# Processed data_257.wav -> processed_networkbent_audio\processed_data_257.wav
# Processed data_258.wav -> processed_networkbent_audio\processed_data_258.wav
# Processed data_259.wav -> processed_networkbent_audio\processed_data_259.wav
# Processed data_26.wav -> processed_networkbent_audio\processed_data_26.wav
# Processed data_260.wav -> processed_networkbent_audio\processed_data_260.wav
# Processed data_261.wav -> processed_networkbent_audio\processed_data_261.wav
# Processed data_262.wav -> processed_networkbent_audio\processed_data_262.wav
# Processed data_263.wav -> processed_networkbent_audio\processed_data_263.wav
# Processed data_264.wav -> processed_networkbent_audio\processed_data_264.wav
# Processed data_265.wav -> processed_networkbent_audio\processed_data_265.wav
# Processed data_266.wav -> processed_networkbent_audio\processed_data_266.wav
# Processed data_267.wav -> processed_networkbent_audio\processed_data_267.wav
# Processed data_268.wav -> processed_networkbent_audio\processed_data_268.wav
# Processed data_269.wav -> processed_networkbent_audio\processed_data_269.wav
# Processed data_27.wav -> processed_networkbent_audio\processed_data_27.wav
# Processed data_270.wav -> processed_networkbent_audio\processed_data_270.wav
# Processed data_271.wav -> processed_networkbent_audio\processed_data_271.wav
# Processed data_272.wav -> processed_networkbent_audio\processed_data_272.wav
# Processed data_273.wav -> processed_networkbent_audio\processed_data_273.wav
# Processed data_274.wav -> processed_networkbent_audio\processed_data_274.wav
# Processed data_275.wav -> processed_networkbent_audio\processed_data_275.wav
# Processed data_276.wav -> processed_networkbent_audio\processed_data_276.wav
# Processed data_277.wav -> processed_networkbent_audio\processed_data_277.wav
# Processed data_278.wav -> processed_networkbent_audio\processed_data_278.wav
# Processed data_279.wav -> processed_networkbent_audio\processed_data_279.wav
# Processed data_28.wav -> processed_networkbent_audio\processed_data_28.wav
# Processed data_280.wav -> processed_networkbent_audio\processed_data_280.wav
# Processed data_281.wav -> processed_networkbent_audio\processed_data_281.wav
# Processed data_282.wav -> processed_networkbent_audio\processed_data_282.wav
# Processed data_283.wav -> processed_networkbent_audio\processed_data_283.wav
# Processed data_284.wav -> processed_networkbent_audio\processed_data_284.wav
# Processed data_285.wav -> processed_networkbent_audio\processed_data_285.wav
# Processed data_286.wav -> processed_networkbent_audio\processed_data_286.wav
# Processed data_287.wav -> processed_networkbent_audio\processed_data_287.wav
# Processed data_288.wav -> processed_networkbent_audio\processed_data_288.wav
# Processed data_289.wav -> processed_networkbent_audio\processed_data_289.wav
# Processed data_29.wav -> processed_networkbent_audio\processed_data_29.wav
# Processed data_290.wav -> processed_networkbent_audio\processed_data_290.wav
# Processed data_291.wav -> processed_networkbent_audio\processed_data_291.wav
# Processed data_292.wav -> processed_networkbent_audio\processed_data_292.wav
# Processed data_293.wav -> processed_networkbent_audio\processed_data_293.wav
# Processed data_294.wav -> processed_networkbent_audio\processed_data_294.wav
# Processed data_295.wav -> processed_networkbent_audio\processed_data_295.wav
# Processed data_296.wav -> processed_networkbent_audio\processed_data_296.wav
# Processed data_297.wav -> processed_networkbent_audio\processed_data_297.wav
# Processed data_298.wav -> processed_networkbent_audio\processed_data_298.wav
# Processed data_299.wav -> processed_networkbent_audio\processed_data_299.wav
# Processed data_3.wav -> processed_networkbent_audio\processed_data_3.wav
# Processed data_30.wav -> processed_networkbent_audio\processed_data_30.wav
# Processed data_300.wav -> processed_networkbent_audio\processed_data_300.wav
# Processed data_301.wav -> processed_networkbent_audio\processed_data_301.wav
# Processed data_302.wav -> processed_networkbent_audio\processed_data_302.wav
# Processed data_303.wav -> processed_networkbent_audio\processed_data_303.wav
# Processed data_304.wav -> processed_networkbent_audio\processed_data_304.wav
# Processed data_305.wav -> processed_networkbent_audio\processed_data_305.wav
# Processed data_306.wav -> processed_networkbent_audio\processed_data_306.wav
# Processed data_307.wav -> processed_networkbent_audio\processed_data_307.wav
# Processed data_308.wav -> processed_networkbent_audio\processed_data_308.wav
# Processed data_309.wav -> processed_networkbent_audio\processed_data_309.wav
# Processed data_31.wav -> processed_networkbent_audio\processed_data_31.wav
# Processed data_310.wav -> processed_networkbent_audio\processed_data_310.wav
# Processed data_311.wav -> processed_networkbent_audio\processed_data_311.wav
# Processed data_312.wav -> processed_networkbent_audio\processed_data_312.wav
# Processed data_313.wav -> processed_networkbent_audio\processed_data_313.wav
# Processed data_314.wav -> processed_networkbent_audio\processed_data_314.wav
# Processed data_315.wav -> processed_networkbent_audio\processed_data_315.wav
# Processed data_316.wav -> processed_networkbent_audio\processed_data_316.wav
# Processed data_317.wav -> processed_networkbent_audio\processed_data_317.wav
# Processed data_318.wav -> processed_networkbent_audio\processed_data_318.wav
# Processed data_319.wav -> processed_networkbent_audio\processed_data_319.wav
# Processed data_32.wav -> processed_networkbent_audio\processed_data_32.wav
# Processed data_320.wav -> processed_networkbent_audio\processed_data_320.wav
# Processed data_321.wav -> processed_networkbent_audio\processed_data_321.wav
# Processed data_322.wav -> processed_networkbent_audio\processed_data_322.wav
# Processed data_323.wav -> processed_networkbent_audio\processed_data_323.wav
# Processed data_324.wav -> processed_networkbent_audio\processed_data_324.wav
# Processed data_325.wav -> processed_networkbent_audio\processed_data_325.wav
# Processed data_326.wav -> processed_networkbent_audio\processed_data_326.wav
# Processed data_327.wav -> processed_networkbent_audio\processed_data_327.wav
# Processed data_328.wav -> processed_networkbent_audio\processed_data_328.wav
# Processed data_329.wav -> processed_networkbent_audio\processed_data_329.wav
# Processed data_33.wav -> processed_networkbent_audio\processed_data_33.wav
# Processed data_330.wav -> processed_networkbent_audio\processed_data_330.wav
# Processed data_331.wav -> processed_networkbent_audio\processed_data_331.wav
# Processed data_332.wav -> processed_networkbent_audio\processed_data_332.wav
# Processed data_333.wav -> processed_networkbent_audio\processed_data_333.wav
# Processed data_334.wav -> processed_networkbent_audio\processed_data_334.wav
# Processed data_335.wav -> processed_networkbent_audio\processed_data_335.wav
# Processed data_336.wav -> processed_networkbent_audio\processed_data_336.wav
# Processed data_337.wav -> processed_networkbent_audio\processed_data_337.wav
# Processed data_338.wav -> processed_networkbent_audio\processed_data_338.wav
# Processed data_339.wav -> processed_networkbent_audio\processed_data_339.wav
# Processed data_34.wav -> processed_networkbent_audio\processed_data_34.wav
# Processed data_340.wav -> processed_networkbent_audio\processed_data_340.wav
# Processed data_341.wav -> processed_networkbent_audio\processed_data_341.wav
# Processed data_342.wav -> processed_networkbent_audio\processed_data_342.wav
# Processed data_343.wav -> processed_networkbent_audio\processed_data_343.wav
# Processed data_344.wav -> processed_networkbent_audio\processed_data_344.wav
# Processed data_345.wav -> processed_networkbent_audio\processed_data_345.wav
# Processed data_346.wav -> processed_networkbent_audio\processed_data_346.wav
# Processed data_347.wav -> processed_networkbent_audio\processed_data_347.wav
# Processed data_348.wav -> processed_networkbent_audio\processed_data_348.wav
# Processed data_349.wav -> processed_networkbent_audio\processed_data_349.wav
# Processed data_35.wav -> processed_networkbent_audio\processed_data_35.wav
# Processed data_350.wav -> processed_networkbent_audio\processed_data_350.wav
# Processed data_351.wav -> processed_networkbent_audio\processed_data_351.wav
# Processed data_352.wav -> processed_networkbent_audio\processed_data_352.wav
# Processed data_353.wav -> processed_networkbent_audio\processed_data_353.wav
# Processed data_354.wav -> processed_networkbent_audio\processed_data_354.wav
# Processed data_355.wav -> processed_networkbent_audio\processed_data_355.wav
# Processed data_356.wav -> processed_networkbent_audio\processed_data_356.wav
# Processed data_357.wav -> processed_networkbent_audio\processed_data_357.wav
# Processed data_358.wav -> processed_networkbent_audio\processed_data_358.wav
# Processed data_359.wav -> processed_networkbent_audio\processed_data_359.wav
# Processed data_36.wav -> processed_networkbent_audio\processed_data_36.wav
# Processed data_360.wav -> processed_networkbent_audio\processed_data_360.wav
# Processed data_361.wav -> processed_networkbent_audio\processed_data_361.wav
# Processed data_362.wav -> processed_networkbent_audio\processed_data_362.wav
# Processed data_363.wav -> processed_networkbent_audio\processed_data_363.wav
# Processed data_364.wav -> processed_networkbent_audio\processed_data_364.wav
# Processed data_365.wav -> processed_networkbent_audio\processed_data_365.wav
# Processed data_366.wav -> processed_networkbent_audio\processed_data_366.wav
# Processed data_367.wav -> processed_networkbent_audio\processed_data_367.wav
# Processed data_368.wav -> processed_networkbent_audio\processed_data_368.wav
# Processed data_369.wav -> processed_networkbent_audio\processed_data_369.wav
# Processed data_37.wav -> processed_networkbent_audio\processed_data_37.wav
# Processed data_370.wav -> processed_networkbent_audio\processed_data_370.wav
# Processed data_371.wav -> processed_networkbent_audio\processed_data_371.wav
# Processed data_372.wav -> processed_networkbent_audio\processed_data_372.wav
# Processed data_373.wav -> processed_networkbent_audio\processed_data_373.wav
# Processed data_374.wav -> processed_networkbent_audio\processed_data_374.wav
# Processed data_375.wav -> processed_networkbent_audio\processed_data_375.wav
# Processed data_376.wav -> processed_networkbent_audio\processed_data_376.wav
# Processed data_377.wav -> processed_networkbent_audio\processed_data_377.wav
# Processed data_378.wav -> processed_networkbent_audio\processed_data_378.wav
# Processed data_379.wav -> processed_networkbent_audio\processed_data_379.wav
# Processed data_38.wav -> processed_networkbent_audio\processed_data_38.wav
# Processed data_380.wav -> processed_networkbent_audio\processed_data_380.wav
# Processed data_381.wav -> processed_networkbent_audio\processed_data_381.wav
# Processed data_382.wav -> processed_networkbent_audio\processed_data_382.wav
# Processed data_383.wav -> processed_networkbent_audio\processed_data_383.wav
# Processed data_384.wav -> processed_networkbent_audio\processed_data_384.wav
# Processed data_385.wav -> processed_networkbent_audio\processed_data_385.wav
# Processed data_386.wav -> processed_networkbent_audio\processed_data_386.wav
# Processed data_387.wav -> processed_networkbent_audio\processed_data_387.wav
# Processed data_388.wav -> processed_networkbent_audio\processed_data_388.wav
# Processed data_389.wav -> processed_networkbent_audio\processed_data_389.wav
# Processed data_39.wav -> processed_networkbent_audio\processed_data_39.wav
# Processed data_390.wav -> processed_networkbent_audio\processed_data_390.wav
# Processed data_391.wav -> processed_networkbent_audio\processed_data_391.wav
# Processed data_392.wav -> processed_networkbent_audio\processed_data_392.wav
# Processed data_393.wav -> processed_networkbent_audio\processed_data_393.wav
# Processed data_394.wav -> processed_networkbent_audio\processed_data_394.wav
# Processed data_395.wav -> processed_networkbent_audio\processed_data_395.wav
# Processed data_396.wav -> processed_networkbent_audio\processed_data_396.wav
# Processed data_397.wav -> processed_networkbent_audio\processed_data_397.wav
# Processed data_398.wav -> processed_networkbent_audio\processed_data_398.wav
# Processed data_399.wav -> processed_networkbent_audio\processed_data_399.wav
# Processed data_4.wav -> processed_networkbent_audio\processed_data_4.wav
# Processed data_40.wav -> processed_networkbent_audio\processed_data_40.wav
# Processed data_400.wav -> processed_networkbent_audio\processed_data_400.wav
# Processed data_401.wav -> processed_networkbent_audio\processed_data_401.wav
# Processed data_402.wav -> processed_networkbent_audio\processed_data_402.wav
# Processed data_403.wav -> processed_networkbent_audio\processed_data_403.wav
# Processed data_404.wav -> processed_networkbent_audio\processed_data_404.wav
# Processed data_405.wav -> processed_networkbent_audio\processed_data_405.wav
# Processed data_406.wav -> processed_networkbent_audio\processed_data_406.wav
# Processed data_407.wav -> processed_networkbent_audio\processed_data_407.wav
# Processed data_408.wav -> processed_networkbent_audio\processed_data_408.wav
# Processed data_409.wav -> processed_networkbent_audio\processed_data_409.wav
# Processed data_41.wav -> processed_networkbent_audio\processed_data_41.wav
# Processed data_410.wav -> processed_networkbent_audio\processed_data_410.wav
# Processed data_411.wav -> processed_networkbent_audio\processed_data_411.wav
# Processed data_412.wav -> processed_networkbent_audio\processed_data_412.wav
# Processed data_413.wav -> processed_networkbent_audio\processed_data_413.wav
# Processed data_414.wav -> processed_networkbent_audio\processed_data_414.wav
# Processed data_415.wav -> processed_networkbent_audio\processed_data_415.wav
# Processed data_416.wav -> processed_networkbent_audio\processed_data_416.wav
# Processed data_417.wav -> processed_networkbent_audio\processed_data_417.wav
# Processed data_418.wav -> processed_networkbent_audio\processed_data_418.wav
# Processed data_419.wav -> processed_networkbent_audio\processed_data_419.wav
# Processed data_42.wav -> processed_networkbent_audio\processed_data_42.wav
# Processed data_420.wav -> processed_networkbent_audio\processed_data_420.wav
# Processed data_421.wav -> processed_networkbent_audio\processed_data_421.wav
# Processed data_422.wav -> processed_networkbent_audio\processed_data_422.wav
# Processed data_423.wav -> processed_networkbent_audio\processed_data_423.wav
# Processed data_424.wav -> processed_networkbent_audio\processed_data_424.wav
# Processed data_425.wav -> processed_networkbent_audio\processed_data_425.wav
# Processed data_426.wav -> processed_networkbent_audio\processed_data_426.wav
# Processed data_427.wav -> processed_networkbent_audio\processed_data_427.wav
# Processed data_428.wav -> processed_networkbent_audio\processed_data_428.wav
# Processed data_429.wav -> processed_networkbent_audio\processed_data_429.wav
# Processed data_43.wav -> processed_networkbent_audio\processed_data_43.wav
# Processed data_430.wav -> processed_networkbent_audio\processed_data_430.wav
# Processed data_431.wav -> processed_networkbent_audio\processed_data_431.wav
# Processed data_432.wav -> processed_networkbent_audio\processed_data_432.wav
# Processed data_433.wav -> processed_networkbent_audio\processed_data_433.wav
# Processed data_434.wav -> processed_networkbent_audio\processed_data_434.wav
# Processed data_435.wav -> processed_networkbent_audio\processed_data_435.wav
# Processed data_436.wav -> processed_networkbent_audio\processed_data_436.wav
# Processed data_437.wav -> processed_networkbent_audio\processed_data_437.wav
# Processed data_438.wav -> processed_networkbent_audio\processed_data_438.wav
# Processed data_439.wav -> processed_networkbent_audio\processed_data_439.wav
# Processed data_44.wav -> processed_networkbent_audio\processed_data_44.wav
# Processed data_440.wav -> processed_networkbent_audio\processed_data_440.wav
# Processed data_441.wav -> processed_networkbent_audio\processed_data_441.wav
# Processed data_442.wav -> processed_networkbent_audio\processed_data_442.wav
# Processed data_443.wav -> processed_networkbent_audio\processed_data_443.wav
# Processed data_444.wav -> processed_networkbent_audio\processed_data_444.wav
# Processed data_445.wav -> processed_networkbent_audio\processed_data_445.wav
# Processed data_446.wav -> processed_networkbent_audio\processed_data_446.wav
# Processed data_447.wav -> processed_networkbent_audio\processed_data_447.wav
# Processed data_448.wav -> processed_networkbent_audio\processed_data_448.wav
# Processed data_449.wav -> processed_networkbent_audio\processed_data_449.wav
# Processed data_45.wav -> processed_networkbent_audio\processed_data_45.wav
# Processed data_450.wav -> processed_networkbent_audio\processed_data_450.wav
# Processed data_451.wav -> processed_networkbent_audio\processed_data_451.wav
# Processed data_452.wav -> processed_networkbent_audio\processed_data_452.wav
# Processed data_453.wav -> processed_networkbent_audio\processed_data_453.wav
# Processed data_454.wav -> processed_networkbent_audio\processed_data_454.wav
# Processed data_455.wav -> processed_networkbent_audio\processed_data_455.wav
# Processed data_456.wav -> processed_networkbent_audio\processed_data_456.wav
# Processed data_457.wav -> processed_networkbent_audio\processed_data_457.wav
# Processed data_46.wav -> processed_networkbent_audio\processed_data_46.wav
# Processed data_47.wav -> processed_networkbent_audio\processed_data_47.wav
# Processed data_48.wav -> processed_networkbent_audio\processed_data_48.wav
# Processed data_49.wav -> processed_networkbent_audio\processed_data_49.wav
# Processed data_5.wav -> processed_networkbent_audio\processed_data_5.wav
# Processed data_50.wav -> processed_networkbent_audio\processed_data_50.wav
# Processed data_51.wav -> processed_networkbent_audio\processed_data_51.wav
# Processed data_52.wav -> processed_networkbent_audio\processed_data_52.wav
# Processed data_53.wav -> processed_networkbent_audio\processed_data_53.wav
# Processed data_54.wav -> processed_networkbent_audio\processed_data_54.wav
# Processed data_55.wav -> processed_networkbent_audio\processed_data_55.wav
# Processed data_56.wav -> processed_networkbent_audio\processed_data_56.wav
# Processed data_57.wav -> processed_networkbent_audio\processed_data_57.wav
# Processed data_58.wav -> processed_networkbent_audio\processed_data_58.wav
# Processed data_59.wav -> processed_networkbent_audio\processed_data_59.wav
# Processed data_6.wav -> processed_networkbent_audio\processed_data_6.wav
# Processed data_60.wav -> processed_networkbent_audio\processed_data_60.wav
# Processed data_61.wav -> processed_networkbent_audio\processed_data_61.wav
# Processed data_62.wav -> processed_networkbent_audio\processed_data_62.wav
# Processed data_63.wav -> processed_networkbent_audio\processed_data_63.wav
# Processed data_64.wav -> processed_networkbent_audio\processed_data_64.wav
# Processed data_65.wav -> processed_networkbent_audio\processed_data_65.wav
# Processed data_66.wav -> processed_networkbent_audio\processed_data_66.wav
# Processed data_67.wav -> processed_networkbent_audio\processed_data_67.wav
# Processed data_68.wav -> processed_networkbent_audio\processed_data_68.wav
# Processed data_69.wav -> processed_networkbent_audio\processed_data_69.wav
# Processed data_7.wav -> processed_networkbent_audio\processed_data_7.wav
# Processed data_70.wav -> processed_networkbent_audio\processed_data_70.wav
# Processed data_71.wav -> processed_networkbent_audio\processed_data_71.wav
# Processed data_72.wav -> processed_networkbent_audio\processed_data_72.wav
# Processed data_73.wav -> processed_networkbent_audio\processed_data_73.wav
# Processed data_74.wav -> processed_networkbent_audio\processed_data_74.wav
# Processed data_75.wav -> processed_networkbent_audio\processed_data_75.wav
# Processed data_76.wav -> processed_networkbent_audio\processed_data_76.wav
# Processed data_77.wav -> processed_networkbent_audio\processed_data_77.wav
# Processed data_78.wav -> processed_networkbent_audio\processed_data_78.wav
# Processed data_79.wav -> processed_networkbent_audio\processed_data_79.wav
# Processed data_8.wav -> processed_networkbent_audio\processed_data_8.wav
# Processed data_80.wav -> processed_networkbent_audio\processed_data_80.wav
# Processed data_81.wav -> processed_networkbent_audio\processed_data_81.wav
# Processed data_82.wav -> processed_networkbent_audio\processed_data_82.wav
# Processed data_83.wav -> processed_networkbent_audio\processed_data_83.wav
# Processed data_84.wav -> processed_networkbent_audio\processed_data_84.wav
# Processed data_85.wav -> processed_networkbent_audio\processed_data_85.wav
# Processed data_86.wav -> processed_networkbent_audio\processed_data_86.wav
# Processed data_87.wav -> processed_networkbent_audio\processed_data_87.wav
# Processed data_88.wav -> processed_networkbent_audio\processed_data_88.wav
# Processed data_89.wav -> processed_networkbent_audio\processed_data_89.wav
# Processed data_9.wav -> processed_networkbent_audio\processed_data_9.wav
# Processed data_90.wav -> processed_networkbent_audio\processed_data_90.wav
# Processed data_91.wav -> processed_networkbent_audio\processed_data_91.wav
# Processed data_92.wav -> processed_networkbent_audio\processed_data_92.wav
# Processed data_93.wav -> processed_networkbent_audio\processed_data_93.wav
# Processed data_94.wav -> processed_networkbent_audio\processed_data_94.wav
# Processed data_95.wav -> processed_networkbent_audio\processed_data_95.wav
# Processed data_96.wav -> processed_networkbent_audio\processed_data_96.wav
# Processed data_97.wav -> processed_networkbent_audio\processed_data_97.wav
# Processed data_98.wav -> processed_networkbent_audio\processed_data_98.wav
# Processed data_99.wav -> processed_networkbent_audio\processed_data_99.wav
